# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from numpy import pi, linspace, sin
import random

# %%
X = [1,2,3]
Y = [3,4,5]

plt.plot(X,Y,marker='o')
plt.grid()

# %%
k = random.uniform(-5,5)
c = random.uniform(-5,5)

Yp = [0,0]
Yp[0] = k*X[0]+c
Yp[1] = k*X[-1]+c
plt.plot(X,Y,marker='o')
plt.plot([X[0],X[-1]],Yp,marker='o')
plt.grid()
print('Y =', k, '*X + ', c)
# Out:
# Y = -2.11829807326821 *X +  -3.7636147794574173

# %%
data = {X[i]:Y[i] for i in range(len(X))}

# %%
def proceed(x):
    return x*k+c

# %%
rate = 0.001
for i in range(10000):
    x = np.array(random.choice(list(data.keys())))
    true_result = data[x.tolist()]
    out = proceed(x)
    delta = true_result - out
    k += delta*rate*x
    c += delta*rate

Yp = [proceed(X[0]),proceed(X[-1])]
plt.plot(X,Y,marker='o')
plt.plot([X[0],X[-1]],Yp,marker='o')
plt.grid()
print('Y =', k, '*X + ', c)
# Out:
# Y = 1.486131818297102 *X +  0.9094086844251803

# %%
print('delta = ', delta)
# Out:
# delta =  -0.37151933264291603
